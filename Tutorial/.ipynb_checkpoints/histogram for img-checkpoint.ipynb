# %%
import numpy as np
import cv2 
from matplotlib import pyplot as plt

img = np.zeros((200,200), np.uint8)
lenna = cv2.imread("lenna.png",0)

#cv2.rectangle(img, point1, point2, color, thickness)
#cv2.rectangle(img, (0,100), (200,200),(255),  -1 )
#cv2.rectangle(img, (50,0), (100,100),(100),  -1 )

#cv2.imshow("img",img)
#cv2.imshow("lenna", lenna)
#plt.hist(lenna.ravel(), 256, [0,256])
#plt.show()


#b,g,r = cv2.split(lenna)
#cv2.imshow("b",b)
#cv2.imshow("g",g)
#cv2.imshow("r",r)

#plt.hist(b.ravel(), 256, [0,256])
#plt.hist(g.ravel(), 256, [0,256])
#plt.hist(r.ravel(), 256, [0,256])
#plt.show()

hist = cv2.calcHist([lenna], [0], None, [256], [0,256])
plt.plot(hist)
cv2.waitKey(0)
cv2.destroyAllWindows()
